# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/biomass_transport_data.csv")

# %% [markdown]
# # **Data Preprocessing and anlysis**

# %%
df.head()
# Out:
#           Origin  Origin_Lat  Origin_Lon      Destination  Dest_Lat  Dest_Lon  \
# 0        Madurai      9.9252     78.1198        Ahmedabad   23.0225   72.5714
# 1  Visakhapatnam     17.6868     83.2185           Bhopal   23.2599   77.4126
# 2       Guwahati     26.1445     91.7362  Tiruchirappalli   10.7905   78.7047
# 3    Vasai-Virar     19.3914     72.8397        Bengaluru   12.9716   77.5946
# 4         Bhopal     23.2599     77.4126      Navi Mumbai   19.0330   73.0297
#
#    Distance_km     Vehicle_Type Fuel_Type  Fuel_Price_per_unit_INR  \
# 0      1571.32      Small Truck    diesel                     92.0
# 1       865.66     Medium Truck    diesel                     92.0
# 2      2188.12  Tractor Trailer    diesel                     92.0
# 3       875.82      Small Truck    diesel                     92.0
# 4       653.73  Tractor Trailer    diesel                     92.0
#
#    Fuel_Consumption_per_100km  Fuel_Cost_INR  Other_Costs_INR  \
# ...

# %%
df.shape
# Out:
# (1000, 13)

# %%
df=df.drop('Origin',axis=1)

# %%
df=df.drop('Destination',axis=1)

# %%
df
# Out:
#      Origin_Lat  Origin_Lon  Dest_Lat  Dest_Lon  Distance_km     Vehicle_Type  \
# 0        9.9252     78.1198   23.0225   72.5714      1571.32      Small Truck
# 1       17.6868     83.2185   23.2599   77.4126       865.66     Medium Truck
# 2       26.1445     91.7362   10.7905   78.7047      2188.12  Tractor Trailer
# 3       19.3914     72.8397   12.9716   77.5946       875.82      Small Truck
# 4       23.2599     77.4126   19.0330   73.0297       653.73  Tractor Trailer
# ..          ...         ...       ...       ...          ...              ...
# 995      9.9252     78.1198   16.5062   80.6480       781.21           Pickup
# 996     19.0760     72.8777   19.2183   72.9781        19.02     Medium Truck
# 997     17.3850     78.4867   23.7957   86.4304      1091.19        CNG Truck
# 998     22.3039     70.8022   23.7957   86.4304      1606.79           Pickup
# 999     17.3850     78.4867   21.2514   81.6296       541.79  Tractor Trailer
#
# ...

# %%
df.describe()
# Out:
#         Origin_Lat   Origin_Lon     Dest_Lat     Dest_Lon  Distance_km  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     22.425309    78.070098    22.441325    78.189997   993.027130
# std       5.712578     4.598890     5.628135     4.675766   519.171033
# min       9.925200    70.802200     9.925200    70.802200    10.620000
# 25%      18.627800    74.797300    19.033000    74.797300   592.910000
# 50%      22.595800    77.412600    22.719600    77.453800   978.920000
# 75%      26.449900    80.331900    26.449900    80.648000  1356.667500
# max      34.083700    91.736200    34.083700    91.736200  2707.570000
#
#        Fuel_Price_per_unit_INR  Fuel_Consumption_per_100km  Fuel_Cost_INR  \
# count              1000.000000                 1000.000000    1000.000000
# mean                 78.448000                   17.864000   14154.528290
# std                  28.331077                    7.218422   12024.608686
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Origin_Lat                  1000 non-null   float64
#  1   Origin_Lon                  1000 non-null   float64
#  2   Dest_Lat                    1000 non-null   float64
#  3   Dest_Lon                    1000 non-null   float64
#  4   Distance_km                 1000 non-null   float64
#  5   Vehicle_Type                1000 non-null   object
#  6   Fuel_Type                   1000 non-null   object
#  7   Fuel_Price_per_unit_INR     1000 non-null   float64
#  8   Fuel_Consumption_per_100km  1000 non-null   int64
#  9   Fuel_Cost_INR               1000 non-null   float64
#  10  Other_Costs_INR             1000 non-null   float64
#  11  Handling_Fee_INR            1000 non-null   int64
#  12  Total_Price_INR             1000 non-null   float64
# ...

# %%
df['Vehicle_Type'].value_counts()
# Out:
# Vehicle_Type
# CNG Truck          148
# Small Truck        146
# Tractor Trailer    145
# Large Truck        144
# Pickup             142
# Electric Van       138
# Medium Truck       137
# Name: count, dtype: int64

# %%
import seaborn as sns

# %%
sns.scatterplot(x='Origin_Lat',y='Total_Price_INR',data=df)
# Out:
# <Axes: xlabel='Origin_Lat', ylabel='Total_Price_INR'>

# %%
sns.pairplot(df)

# %%
sns.histplot(df['Total_Price_INR'])
# Out:
# <Axes: xlabel='Total_Price_INR', ylabel='Count'>

# %%
sns.kdeplot(df['Total_Price_INR'])
# Out:
# <Axes: xlabel='Total_Price_INR', ylabel='Density'>

# %% [markdown]
# # **Boxplot for outlier detection**

# %%
boxplot=df.boxplot(column=['Total_Price_INR'])

# %%
plt.figure(figsize=(15,5))
sns.barplot(x="Vehicle_Type", y="Fuel_Consumption_per_100km", data=df, estimator="mean", ci=None)
plt.ylabel("Fuel Consumption (per 100 km)")
plt.xlabel("Vehicle Type")
plt.title("Average Fuel Consumption by Vehicle Type")
plt.show()
# Out:
# /tmp/ipython-input-391403619.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="Vehicle_Type", y="Fuel_Consumption_per_100km", data=df, estimator="mean", ci=None)

# %%
plt.figure(figsize=(8,5))
sns.barplot(x="Fuel_Type", y="Fuel_Consumption_per_100km", data=df, estimator="mean", ci=None)
plt.ylabel("Fuel Consumption (per 100 km)")
plt.xlabel("Vehicle Type")
plt.title("Average Fuel Consumption by Vehicle Type")
plt.show()
# Out:
# /tmp/ipython-input-771528874.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="Fuel_Type", y="Fuel_Consumption_per_100km", data=df, estimator="mean", ci=None)

# %%
df2=df.copy()

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

# %%
df2['Vehicle_Type_encoded']=le.fit_transform(df2['Vehicle_Type'])

# %%
df2
# Out:
#      Origin_Lat  Origin_Lon  Dest_Lat  Dest_Lon  Distance_km     Vehicle_Type  \
# 0        9.9252     78.1198   23.0225   72.5714      1571.32      Small Truck
# 1       17.6868     83.2185   23.2599   77.4126       865.66     Medium Truck
# 2       26.1445     91.7362   10.7905   78.7047      2188.12  Tractor Trailer
# 3       19.3914     72.8397   12.9716   77.5946       875.82      Small Truck
# 4       23.2599     77.4126   19.0330   73.0297       653.73  Tractor Trailer
# ..          ...         ...       ...       ...          ...              ...
# 995      9.9252     78.1198   16.5062   80.6480       781.21           Pickup
# 996     19.0760     72.8777   19.2183   72.9781        19.02     Medium Truck
# 997     17.3850     78.4867   23.7957   86.4304      1091.19        CNG Truck
# 998     22.3039     70.8022   23.7957   86.4304      1606.79           Pickup
# 999     17.3850     78.4867   21.2514   81.6296       541.79  Tractor Trailer
#
# ...

# %%
df2['Vehicle_Type_encoded'].value_counts()
# Out:
# Vehicle_Type_encoded
# 0    148
# 5    146
# 6    145
# 2    144
# 4    142
# 1    138
# 3    137
# Name: count, dtype: int64

# %%
df2['Fuel_Type'].value_counts()
# Out:
# Fuel_Type
# diesel      649
# cng         158
# electric    150
# petrol       43
# Name: count, dtype: int64

# %%
df2['Fuel_Type_encoded']=le.fit_transform(df2['Fuel_Type'])

# %%
df2
# Out:
#      Origin_Lat  Origin_Lon  Dest_Lat  Dest_Lon  Distance_km     Vehicle_Type  \
# 0        9.9252     78.1198   23.0225   72.5714      1571.32      Small Truck
# 1       17.6868     83.2185   23.2599   77.4126       865.66     Medium Truck
# 2       26.1445     91.7362   10.7905   78.7047      2188.12  Tractor Trailer
# 3       19.3914     72.8397   12.9716   77.5946       875.82      Small Truck
# 4       23.2599     77.4126   19.0330   73.0297       653.73  Tractor Trailer
# ..          ...         ...       ...       ...          ...              ...
# 995      9.9252     78.1198   16.5062   80.6480       781.21           Pickup
# 996     19.0760     72.8777   19.2183   72.9781        19.02     Medium Truck
# 997     17.3850     78.4867   23.7957   86.4304      1091.19        CNG Truck
# 998     22.3039     70.8022   23.7957   86.4304      1606.79           Pickup
# 999     17.3850     78.4867   21.2514   81.6296       541.79  Tractor Trailer
#
# ...

# %%
df2=df2.drop(['Vehicle_Type','Fuel_Type'],axis=1)

# %%
y=df2['Total_Price_INR']

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Origin_Lat                  1000 non-null   float64
#  1   Origin_Lon                  1000 non-null   float64
#  2   Dest_Lat                    1000 non-null   float64
#  3   Dest_Lon                    1000 non-null   float64
#  4   Distance_km                 1000 non-null   float64
#  5   Fuel_Price_per_unit_INR     1000 non-null   float64
#  6   Fuel_Consumption_per_100km  1000 non-null   int64
#  7   Fuel_Cost_INR               1000 non-null   float64
#  8   Other_Costs_INR             1000 non-null   float64
#  9   Handling_Fee_INR            1000 non-null   int64
#  10  Total_Price_INR             1000 non-null   float64
#  11  Vehicle_Type_encoded        1000 non-null   int64
#  12  Fuel_Type_encoded           1000 non-null   int64
# ...

# %%
y
# Out:
# 0      15177.54
# 1      15278.60
# 2      64124.29
# 3       8570.29
# 4      19473.54
#          ...
# 995     6177.20
# 996      648.67
# 997    14997.42
# 998    10909.09
# 999    16216.09
# Name: Total_Price_INR, Length: 1000, dtype: float64

# %%
x=df2.drop('Total_Price_INR',axis=1)

# %%
x
# Out:
#      Origin_Lat  Origin_Lon  Dest_Lat  Dest_Lon  Distance_km  \
# 0        9.9252     78.1198   23.0225   72.5714      1571.32
# 1       17.6868     83.2185   23.2599   77.4126       865.66
# 2       26.1445     91.7362   10.7905   78.7047      2188.12
# 3       19.3914     72.8397   12.9716   77.5946       875.82
# 4       23.2599     77.4126   19.0330   73.0297       653.73
# ..          ...         ...       ...       ...          ...
# 995      9.9252     78.1198   16.5062   80.6480       781.21
# 996     19.0760     72.8777   19.2183   72.9781        19.02
# 997     17.3850     78.4867   23.7957   86.4304      1091.19
# 998     22.3039     70.8022   23.7957   86.4304      1606.79
# 999     17.3850     78.4867   21.2514   81.6296       541.79
#
#      Fuel_Price_per_unit_INR  Fuel_Consumption_per_100km  Fuel_Cost_INR  \
# 0                       92.0                          10       14456.14
# 1                       92.0                          18       14335.33
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_tr,x_te,y_tr,y_te=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_tr.shape
# Out:
# (800, 12)

# %% [markdown]
# # **Heatmap for correlation**

# %%
plt.figure(figsize=(12,5))
sns.heatmap(df2.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # **Linear Regression**

# %%
from sklearn.linear_model import LinearRegression

# %%
m1=LinearRegression()

# %%
m1.fit(x_tr,y_tr)
# Out:
# LinearRegression()

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Origin_Lat                  1000 non-null   float64
#  1   Origin_Lon                  1000 non-null   float64
#  2   Dest_Lat                    1000 non-null   float64
#  3   Dest_Lon                    1000 non-null   float64
#  4   Distance_km                 1000 non-null   float64
#  5   Fuel_Price_per_unit_INR     1000 non-null   float64
#  6   Fuel_Consumption_per_100km  1000 non-null   int64
#  7   Fuel_Cost_INR               1000 non-null   float64
#  8   Other_Costs_INR             1000 non-null   float64
#  9   Handling_Fee_INR            1000 non-null   int64
#  10  Total_Price_INR             1000 non-null   float64
#  11  Vehicle_Type_encoded        1000 non-null   int64
#  12  Fuel_Type_encoded           1000 non-null   int64
# ...

# %%
y_pre=m1.predict(x_te)

# %%
results = pd.DataFrame({
    'Actual': y_te,
    'Predicted': y_pre
})
results.head()
# Out:
#        Actual     Predicted
# 521  61135.14  61135.140953
# 737   7671.88   7671.878760
# 740   1737.02   1737.019339
# 660   4294.57   4294.581070
# 411  10559.05  10559.049507

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_te,y_pre)
# Out:
# 0.9999999999998604

# %%
tr_prdi=m1.predict(x_tr)

# %%
results2 = pd.DataFrame({
    'Actual': y_tr,
    'Predicted': tr_prdi
})
results2.head()
# Out:
#        Actual     Predicted
# 29    9265.53   9265.539792
# 535   4299.46   4299.460150
# 695  10945.79  10945.789407
# 557  25576.48  25576.479888
# 836   4900.25   4900.250567

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_tr,tr_prdi)
# Out:
# 2.323727635634887e-05

# %%
results = pd.DataFrame({
    'Actual': y_te,
    'Predicted': y_pre2
})
results.head()
# Out:
#        Actual     Predicted
# 521  61135.14  61939.232000
# 737   7671.88   5761.313077
# 740   1737.02   1016.169111
# 660   4294.57   4617.907358
# 411  10559.05  10638.492791

# %%
import numpy as np
from sklearn.metrics import (
    r2_score, mean_squared_error, mean_absolute_error,
    mean_absolute_percentage_error
)

def regression_metrics(y_true, y_pred):
    # Convert to numpy arrays in case inputs are lists
    y_true, y_pred = np.array(y_true), np.array(y_pred)

    metrics = {
        "R2 Score": r2_score(y_true, y_pred),
        "Mean Absolute Error (MAE)": mean_absolute_error(y_true, y_pred),
        "Mean Squared Error (MSE)": mean_squared_error(y_true, y_pred),
        "Root Mean Squared Error (RMSE)": np.sqrt(mean_squared_error(y_true, y_pred)),
        "Mean Absolute Percentage Error (MAPE)": mean_absolute_percentage_error(y_true, y_pred)
    }



    return metrics

# %%
results = regression_metrics(y_te, y_pre)
for metric, value in results.items():
    print(f"{metric}: {value:.4f}")
# Out:
# R2 Score: 1.0000
# Mean Absolute Error (MAE): 0.0023
# Mean Squared Error (MSE): 0.0000
# Root Mean Squared Error (RMSE): 0.0044
# Mean Absolute Percentage Error (MAPE): 0.0000

# %%
results = regression_metrics(y_tr, m1.predict(x_tr))
for metric, value in results.items():
    print(f"{metric}: {value:.4f}")
# Out:
# R2 Score: 1.0000
# Mean Absolute Error (MAE): 0.0027
# Mean Squared Error (MSE): 0.0000
# Root Mean Squared Error (RMSE): 0.0048
# Mean Absolute Percentage Error (MAPE): 0.0000

# %% [markdown]
# # **Lets see how close our predicted values are with the true values**

# %%
y_pred = m1.predict(x_te)
plt.scatter(y_te, y_pred, alpha=0.6)   # y_te, not y
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Linear Regression Predictions vs Actual")
plt.plot([y_te.min(), y_te.max()], [y_te.min(), y_te.max()], "r--")  # reference line
plt.show()

# %% [markdown]
# ## **Now training and testing on decision trees**

# %%
from sklearn.tree import DecisionTreeRegressor

m2 = DecisionTreeRegressor(max_depth=5, random_state=42)

# %%
m2.fit(x_tr,y_tr)
# Out:
# DecisionTreeRegressor(max_depth=5, random_state=42)

# %% [markdown]
# # **Results on Test**

# %%
results = pd.DataFrame({
    'Actual': y_te,
    'Predicted': m2.predict(x_te)
})
results.head()
# Out:
#        Actual     Predicted
# 521  61135.14  61939.232000
# 737   7671.88   5761.313077
# 740   1737.02   1016.169111
# 660   4294.57   4617.907358
# 411  10559.05  10638.492791

# %%
results = regression_metrics(y_te, m2.predict(x_te))
for metric, value in results.items():
    print(f"{metric}: {value:.4f}")
# Out:
# R2 Score: 0.9976
# Mean Absolute Error (MAE): 436.2904
# Mean Squared Error (MSE): 334298.8085
# Root Mean Squared Error (RMSE): 578.1858
# Mean Absolute Percentage Error (MAPE): 0.0658

# %% [markdown]
# # **Results for training set**

# %%
results = pd.DataFrame({
    'Actual': y_tr,
    'Predicted': m2.predict(x_tr)
})
results.head()
# Out:
#        Actual     Predicted
# 29    9265.53   9182.849615
# 535   4299.46   4617.907358
# 695  10945.79  10638.492791
# 557  25576.48  24731.373333
# 836   4900.25   4617.907358

# %%
results = regression_metrics(y_tr, m2.predict(x_tr))
for metric, value in results.items():
    print(f"{metric}: {value:.4f}")
# Out:
# R2 Score: 0.9987
# Mean Absolute Error (MAE): 367.6835
# Mean Squared Error (MSE): 222019.1882
# Root Mean Squared Error (RMSE): 471.1891
# Mean Absolute Percentage Error (MAPE): 0.0641

# %%
features=x.columns
class_names

# %%
features
# Out:
# Index(['Origin_Lat', 'Origin_Lon', 'Dest_Lat', 'Dest_Lon', 'Distance_km',
#        'Fuel_Price_per_unit_INR', 'Fuel_Consumption_per_100km',
#        'Fuel_Cost_INR', 'Other_Costs_INR', 'Handling_Fee_INR',
#        'Vehicle_Type_encoded', 'Fuel_Type_encoded'],
#       dtype='object')

# %% [markdown]
# # **lets visualize decision tree**

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15, 8))
plot_tree(m2,
          feature_names=features,
          filled=True,  # color nodes by value
          rounded=True,
          fontsize=12)
plt.show()

# %% [markdown]
# # **Lets see how close our predictions are with the true values**

# %%
y_pred = m2.predict(x_te)
plt.scatter(y_te, y_pred, alpha=0.6)   # y_te, not y
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Decision Tree Predictions vs Actual")
plt.plot([y_te.min(), y_te.max()], [y_te.min(), y_te.max()], "r--")  # reference line
plt.show()

# %% [markdown]
# # ***Random Forest***

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=100, random_state=42)

# %%
rf.fit(x_tr,y_tr)
# Out:
# RandomForestRegressor(random_state=42)

# %% [markdown]
# # **Performance on test**

# %%
results = regression_metrics(y_te, rf.predict(x_te))
for metric, value in results.items():
    print(f"{metric}: {value:.4f}")
# Out:
# R2 Score: 0.9997
# Mean Absolute Error (MAE): 130.5254
# Mean Squared Error (MSE): 44739.1540
# Root Mean Squared Error (RMSE): 211.5163
# Mean Absolute Percentage Error (MAPE): 0.0133

# %%
y_pred = m2.predict(x_te)
plt.scatter(y_te, y_pred, alpha=0.6)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Random Forest Predictions vs Actual")
plt.plot([y_te.min(), y_te.max()], [y_te.min(), y_te.max()], "r--")
plt.show()

# %% [markdown]
# # **Performance on train**

# %%
results = regression_metrics(y_tr, rf.predict(x_tr))
for metric, value in results.items():
    print(f"{metric}: {value:.4f}")
# Out:
# R2 Score: 0.9999
# Mean Absolute Error (MAE): 50.1478
# Mean Squared Error (MSE): 10472.0743
# Root Mean Squared Error (RMSE): 102.3332
# Mean Absolute Percentage Error (MAPE): 0.0054

# %%
y_pred = m2.predict(x_tr)
plt.scatter(y_tr, y_pred, alpha=0.6)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Random Forest Predictions vs Actual")
plt.plot([y_tr.min(), y_tr.max()], [y_tr.min(), y_tr.max()], "r--")
plt.show()
